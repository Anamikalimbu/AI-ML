# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/employee_data_messy (1).csv")

# %%
print("---Data Summary---")
df.info()
# Out:
# ---Data Summary---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   35 non-null     int64
#  1   Name         35 non-null     object
#  2   Age          33 non-null     object
#  3   Salary       34 non-null     object
#  4   Department   34 non-null     object
#  5   JoiningDate  34 non-null     object
#  6   Email        34 non-null     object
#  7   City         34 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 2.3+ KB

# %%
print("\n---Missing Value Tally---")
print(df.isnull().sum())
# Out:
# ---Missing Value Tally---
# EmployeeID     0
# Name           0
# Age            2
# Salary         1
# Department     1
# JoiningDate    1
# Email          1
# City           1
# dtype: int64

# %%
#Drop rows where critical identifying criteria is absent (eg. name)
df_clean = df.dropna(subset=["Name"])

# %%
print(df_clean.head(5))
# Out:
#    EmployeeID          Name     Age Salary Department JoiningDate  \
# 0         101     John Doe       25  50000         IT  2022-01-15
# 1         102    Jane Smith      28  55000         HR  2021-11-10
# 2         103  Mike Johnson     NaN  62000    Finance  2020-05-20
# 3         104  Sarah Wilson  Thirty  58000         IT  2022-03-12
# 4         105   David Brown      35    NaN  Marketing  2019-07-01
#
#                     Email       City
# 0      john.doe@gmail.com  Kathmandu
# 1    jane.smith@gmail.com    Pokhara
# 2  mike.johnson@gmail.com   Lalitpur
# 3  sarah.wilson@gmail.com  Bhaktapur
# 4   david.brown@gmail.com     Butwal

# %%
#imputing and converting non numeric values
df_clean['Salary']=df_clean["Salary"].astype(str).replace(',','',regex=False)
df_clean['Salary']=pd.to_numeric(df_clean['Salary'],errors='coerce')
salary_median = df_clean['Salary'].median()
df_clean['Salary'] = df_clean['Salary'].fillna(salary_median)

# %%
#replaceing missing categorical fields (Department) with a descriptive text "Unassigned"
df_clean['Department'] = df_clean['Department'].fillna('Unassigned')

# %%
print("---Missing Value After Initial Fixes")
print(df_clean.isnull().sum()[['Name','Salary','Department']])
# Out:
# ---Missing Value After Initial Fixes
# Name          0
# Salary        0
# Department    0
# dtype: int64

# %%
duplicate_count = df_clean.duplicated().sum()
print(f"Total perfect duplicate roun found: {duplicate_count}")
# Out:
# Total perfect duplicate roun found: 0

# %%
#redundant rows
df_clean = df_clean.drop_duplicates()
print(f"Total valid unique records remaining: {len(df_clean)}")
# Out:
# Total valid unique records remaining: 35

# %%
#Replace alphabetical text entry strings with actual numerical string metrics
df_clean["Age"] = df_clean["Age"].replace("Thirty", "30")
df_clean["Age"] = df_clean["Age"].replace("twenty-eight","28")

# %%
#Coerce the column values to a numeric datatype safely
df_clean['Age']=pd.to_numeric(df_clean['Age'], errors='coerce')

# %%
# Fill any new NaN values(from broken parsing) with column median, then cast to  integer
age_median = df_clean["Age"].median()
df_clean['Age']= df_clean['Age'].fillna(age_median).astype(int)

# %%
df_clean["JoiningDate"]=pd.to_datetime(df_clean['JoiningDate'],errors='coerce')

# %%
# Standaridze and transform date string into true Datetime format structures
print("---Structural Data Type Conversion Verified---")
print(df_clean[['Age','JoiningDate']].dtypes)
# Out:
# ---Structural Data Type Conversion Verified---
# Age                     int64
# JoiningDate    datetime64[ns]
# dtype: object

# %%
df_clean["Name"]=df_clean["Name"].str.strip()
df_clean["City"]=df_clean["City"].str.strip()

# %%
df_clean["Name"]=df_clean["Name"].str.title()
df_clean["City"]=df_clean["City"].str.title()

# %%
df_clean['Department']=df_clean['Department'].str.upper()

# %%
#Fill remaining missing city spaces with a standard placeholder value
df_clean['City']=df_clean['City'].fillna('Unknown')

# %%
print("---Cleaned Text Field---")
print(df_clean[["Name","Age","Department","City"]].head(10))
# Out:
# ---Cleaned Text Field---
#              Name  Age  Department       City
# 0        John Doe   25          IT  Kathmandu
# 1      Jane Smith   28          HR    Pokhara
# 2    Mike Johnson   29     FINANCE   Lalitpur
# 3    Sarah Wilson   30          IT  Bhaktapur
# 4     David Brown   35   MARKETING     Butwal
# 5     Emily Davis   29          HR    Chitwan
# 6    Chris Taylor   31     FINANCE     Dharan
# 7  Jessica Miller   27          IT  Kathmandu
# 8    Robert White   40  MANAGEMENT    Pokhara
# 9      Lisa Green   26          HR   Janakpur

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   35 non-null     int64
#  1   Name         35 non-null     object
#  2   Age          35 non-null     int64
#  3   Salary       35 non-null     float64
#  4   Department   35 non-null     object
#  5   JoiningDate  33 non-null     datetime64[ns]
#  6   Email        35 non-null     object
#  7   City         35 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 2.3+ KB

# %%
df_clean['Email']= df_clean['Email'].fillna("Unknown")

# %%
print(df_clean[["Name",'Email']].head(10))
# Out:
#              Name                   Email
# 0        John Doe      john.doe@gmail.com
# 1      Jane Smith    jane.smith@gmail.com
# 2    Mike Johnson  mike.johnson@gmail.com
# 3    Sarah Wilson  sarah.wilson@gmail.com
# 4     David Brown   david.brown@gmail.com
# 5     Emily Davis   emily.davis@gmail.com
# 6    Chris Taylor  chris.taylor@gmail.com
# 7  Jessica Miller                 Unknown
# 8    Robert White  robert.white@gmail.com
# 9      Lisa Green        lisa.green@gmail

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   35 non-null     int64
#  1   Name         35 non-null     object
#  2   Age          35 non-null     int64
#  3   Salary       35 non-null     float64
#  4   Department   35 non-null     object
#  5   JoiningDate  33 non-null     datetime64[ns]
#  6   Email        35 non-null     object
#  7   City         35 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 2.3+ KB
