# %%
customer_id = 1 014
customer_name = "Anamika Limbu"
monthly_spend = 89.50
is_preminum_member = True

# %%
total_yearly_spend = monthly_spend * 12
discount_spend = monthly_spend - (monthly_spend *0.10)

print("Customer:",customer_name)
print("Yearly Spend: ",total_yearly_spend)
print("Discount Price: ",discount_spend)
# Out:
# Customer: Anamika Limbu
# Yearly Spend:  1074.0
# Discount Price:  80.55

# %%
puraches_amount = 150.0

if puraches_amount >= 200:
  customer_tier = "Platinum"
elif puraches_amount >= 100:
  customer_tier = "Gold"
else:
  customer_tier = "Silver"

# %%
print(f'Customer Tier:{customer_tier}')
# Out:
# Customer Tier:Gold

# %%
transactions = [45.0, 120.5, 8.99, 250.0, 75.25]
total_revenue = 0.0
for sale in transactions:
  total_revenue += sale

# %%
print(f"Total Revenue for the day: ${total_revenue}")
# Out:
# Total Revenue for the day: $499.74

# %%
def calculate_tax(amount, tax_rate=0.08):
  """Calculates sales tax for a given transaction amount"""
  sales_tax = amount * tax_rate
  return round(sales_tax,2)

# %%
item_price = 125.0
tax_due = calculate_tax(item_price)
print(f"Tax on ${item_price} : ${tax_due}")
# Out:
# Tax on $125.0 : $10.0

# %%
import math
total_items = 105
items_per_page = 10
total_pages = math.ceil(total_items / items_per_page)
print(f"Total pages needed for reporting dashboard: {total_pages}")
# Out:
# Total pages needed for reporting dashboard: 11
