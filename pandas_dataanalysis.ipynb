# %%
import pandas as pd
import numpy as np

# %%
#Creating a Pandas Series Manually
math_grades = [78, 88, 67]
grades_series = pd.Series(math_grades, name = "Math_Score")
print("---Pandas Series---")
print(grades_series)
# Out:
# ---Pandas Series---
# 0    78
# 1    88
# 2    67
# Name: Math_Score, dtype: int64

# %%
# Creating a small Pandas Data Frame manually from a Dictionary

student_dict ={
    "StudentID": ["S001", "S002", "S003"],
    "Name": ["Aarav Sharma", "Neha Limbu", "Rohan Karki"],
    "Course": ["Computing", "Computing", "Business"]
}
small_df = pd.DataFrame(student_dict)
print("\n--- Pandas DataFrame ---")
print(small_df)
# Out:
# --- Pandas DataFrame ---
#   StudentID          Name     Course
# 0      S001  Aarav Sharma  Computing
# 1      S002    Neha Limbu  Computing
# 2      S003   Rohan Karki   Business

# %%
df_students = pd.read_csv("/content/students_pandas_day4 (1).csv")
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %%
#1. Look at the first 5 records
print("---Top 5 Row (.head)---")
print(df_students.head(10))
# Out:
# ---Top 5 Row (.head)---
#   StudentID            Name Gender  Age       Course  Maths  Science  English  \
# 0      S001    Aarav Sharma      M   19    Computing     78       85       72
# 1      S002      Neha Limbu      F   20    Computing     88       91       84
# 2      S003     Rohan Karki      M   18     Business     67       74       70
# 3      S004        Sita Rai      F   21    Computing     92       89       95
# 4      S005    Bikash Thapa      M   20  Engineering     81       77       79
# 5      S006    Anita Gurung      F   19     Business     75       82       87
# 6      S007     Suman Karki      M   22  Engineering     69       65       73
# 7      S008  Pooja Shrestha      F   18    Computing     95       97       94
# 8      S009     Ram Bahadur      M   21     Business     58       62       60
# 9      S010  Kriti Adhikari      F   20  Engineering     84       88       86
#
#    Attendance
# 0          92
# 1          95
# 2          88
# 3          98
# 4          90
# 5          93
# 6          85
# 7          99
# 8          80
# 9          96

# %%
#2. Check the structural layout and data types
df_students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   15 non-null     object
#  1   Name        15 non-null     object
#  2   Gender      15 non-null     object
#  3   Age         15 non-null     int64
#  4   Course      15 non-null     object
#  5   Maths       15 non-null     int64
#  6   Science     15 non-null     int64
#  7   English     15 non-null     int64
#  8   Attendance  15 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 1.2+ KB

# %%
#3. Generate summary statistics for numeric scores
print("\n---Statistics Summary (.describe)---")
print(df_students.describe())
# Out:
# ---Statistics Summary (.describe)---
#              Age      Maths    Science    English  Attendance
# count  15.000000  15.000000  15.000000  15.000000     15.0000
# mean   19.933333  78.466667  80.466667  80.066667     91.0000
# std     1.279881  10.914385  10.615801  10.463997      5.8064
# min    18.000000  58.000000  62.000000  60.000000     80.0000
# 25%    19.000000  71.000000  73.000000  72.500000     87.5000
# 50%    20.000000  78.000000  82.000000  80.000000     92.0000
# 75%    21.000000  87.000000  88.500000  87.500000     95.5000
# max    22.000000  95.000000  97.000000  95.000000     99.0000

# %%
print("\nShape (Rows, Columns):", df_students.shape)
# Out:
# Shape (Rows, Columns): (15, 9)

# %%
names_column = df_students["Name"]
grades_df = df_students [["Name", "Maths", "Science"]]

# %%
computing_filter = df_students["Course"]== "Computing"
computing_students = df_students[computing_filter]

# %%
#3. Advance Filtering
high_achievers = df_students[(df_students["Maths"]>=80)&(df_students["Attendance"]>=80)]

# %%
print("---Computing Course Students---")
print(computing_students[["Name","Course"]])
print("\n---High Achievers---")
print(high_achievers[["Name", "Maths", "Attendance"]])
# Out:
# ---Computing Course Students---
#               Name     Course
# 0     Aarav Sharma  Computing
# 1       Neha Limbu  Computing
# 3         Sita Rai  Computing
# 7   Pooja Shrestha  Computing
# 10   Manish Tamang  Computing
# 13         Rita KC  Computing
#
# ---High Achievers---
#               Name  Maths  Attendance
# 1       Neha Limbu     88          95
# 3         Sita Rai     92          98
# 4     Bikash Thapa     81          90
# 7   Pooja Shrestha     95          99
# 9   Kriti Adhikari     84          96
# 11    Sabina Magar     90          97
# 13         Rita KC     86          94

# %%
# Sorting
top_attendance = df_students.sort_values(by="Attendance", ascending=False)
print(top_attendance)
# Out:
#    StudentID            Name Gender  Age       Course  Maths  Science  \
# 7       S008  Pooja Shrestha      F   18    Computing     95       97
# 3       S004        Sita Rai      F   21    Computing     92       89
# 11      S012    Sabina Magar      F   22     Business     90       85
# 9       S010  Kriti Adhikari      F   20  Engineering     84       88
# 1       S002      Neha Limbu      F   20    Computing     88       91
# 13      S014         Rita KC      F   19    Computing     86       93
# 5       S006    Anita Gurung      F   19     Business     75       82
# 0       S001    Aarav Sharma      M   19    Computing     78       85
# 4       S005    Bikash Thapa      M   20  Engineering     81       77
# 10      S011   Manish Tamang      M   19    Computing     73       79
# 2       S003     Rohan Karki      M   18     Business     67       74
# 12      S013     Prakash Oli      M   20  Engineering     77       72
# 6       S007     Suman Karki      M   22  Engineering     69       65
# 14      S015    Dipesh Bista      M   21     Business     64       68
# 8       S009     Ram Bahadur      M   21     Business     58       62
#
#     English  Attendance
# 7        94          99
# 3        95          98
# 11       91          97
# 9        86          96
# 1        84          95
# 13       88          94
# 5        87          93
# 0        72          92
# 4        79          90
# 10       76          89
# 2        70          88
# 12       80          87
# 6        73          85
# 14       66          82
# 8        60          80

# %%
# accessing cells using label based indexing (.loc)
print(df_students.head(3))
students_course_loc = df_students.loc[1, "Name"]
print(students_course_loc)
# Out:
#   StudentID          Name Gender  Age     Course  Maths  Science  English  \
# 0      S001  Aarav Sharma      M   19  Computing     78       85       72
# 1      S002    Neha Limbu      F   20  Computing     88       91       84
# 2      S003   Rohan Karki      M   18   Business     67       74       70
#
#    Attendance
# 0          92
# 1          95
# 2          88
# Neha Limbu

# %%
# Accessing cells using iloc
student_maths_iloc = df_students.iloc[1:3,5:8]
print(student_maths_iloc)
# Out:
#    Maths  Science  English
# 1     88       91       84
# 2     67       74       70

# %%
print(df_students.tail(3))
# Out:
#    StudentID          Name Gender  Age       Course  Maths  Science  English  \
# 12      S013   Prakash Oli      M   20  Engineering     77       72       80
# 13      S014       Rita KC      F   19    Computing     86       93       88
# 14      S015  Dipesh Bista      M   21     Business     64       68       66
#
#     Attendance
# 12          87
# 13          94
# 14          82

# %%
# filtering
student_filtering = df_students[(df_students["Gender"]== "F")&(df_students["Course"]=="Business")]
print(student_filtering[["Name", "Gender", "Course"]])
# Out:
#             Name Gender    Course
# 5   Anita Gurung      F  Business
# 11  Sabina Magar      F  Business

# %%
# sorting
high_score = df_students.sort_values(by="Science", ascending=False)
print(high_score[["Name", "Science"]].head())
# Out:
#               Name  Science
# 7   Pooja Shrestha       97
# 13         Rita KC       93
# 1       Neha Limbu       91
# 3         Sita Rai       89
# 9   Kriti Adhikari       88

# %%
df_students["Total_Score"]= df_students["Maths"] + df_students["Science"] + df_students["English"]

# %%
print(df_students.head())
# Out:
#   StudentID          Name Gender  Age       Course  Maths  Science  English  \
# 0      S001  Aarav Sharma      M   19    Computing     78       85       72
# 1      S002    Neha Limbu      F   20    Computing     88       91       84
# 2      S003   Rohan Karki      M   18     Business     67       74       70
# 3      S004      Sita Rai      F   21    Computing     92       89       95
# 4      S005  Bikash Thapa      M   20  Engineering     81       77       79
#
#    Attendance  Total_Score
# 0          92          235
# 1          95          263
# 2          88          211
# 3          98          276
# 4          90          237
